# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # https://www.kaggle.com/ekami66/detailed-exploratory-data-analysis-with-python

# %% [markdown]
# # 1.0 Matplotlib Basics

# %% [markdown]
# ## Was ist Matplotlib?
# Matplotlib ist eine Programmbibliothek für die Programmiersprache Python, die es erlaubt mathematische Darstellungen aller Art anzufertigen.

# %% [markdown]
# ### <font color='red'>plt.plot()</font> $\Rightarrow$ Ermöglicht uns simple mathematische Zusammenhänge zu visualisieren
#
# ### Schema: plt.plot([x], y, [fmt], ...)

# %%
plt.plot([1,2,3,4]);

# %% [markdown]
# X ist optional, da der Index (die Stelle an der y in bspw. einer Liste steht), implizit als Wert angenommen wird!

# %%
x = [1, 2, 3, 4]
y = [i ** 2 for i in x]
plt.plot(x,y);

# %% [markdown]
# ## Bringen wir <font color='green'>Farben</font> <font color='blue'>und</font> <font color='red'>Formen</font> ins Spiel
#
# Für kontinuierliche Datenpunkte (Linien) gibt es folgende Arten der Visualisierung:
#
# * linestyle = ('-', '-', '-.', ':', '')
# * linestyle = ('solid', 'dotted', 'dashed', 'dashdot', 'loosely dotted', 'densely dotted', ...)
#
#
# Für Marker gibt es folgende Arten der Visualisierung:
#
# * marker = ('o', 'v', '^', '<', '>', '8', 's', 'p', '*', 'h', 'H', 'D', 'd', 'P', 'X')
#
#
# ### Gekennzeichnet wird im Aufruf der Funktion wie folgt:
# * plt.plot(x, y, <font color='red'>'o'</font>)
# * plt.plot(x, y, <font color='red'>'--'</font>)

# %%
plt.plot(x, y, 'o')
plt.show();
plt.plot(x, y, marker='X')
plt.show();
plt.plot(x, y, '--')
plt.show();
plt.plot(x, y, linestyle='dashed')
plt.show();

# %% [markdown]
# ### <font color='red'>plt.show()</font> $\Rightarrow$ Zeigt den tatsächlichen Plot (für Notebooks nicht so wichtig, da ohnehin angezeigt. Für Skript wichtig, da Ergebnis sonst zwar erstellt, aber nicht angezeigt wird) an.

# %%
y = [1,2,3,4,5]
plt.plot(y);

# %%
y = [1,2,3,4,5]
plt.plot(y)
plt.show;

# %% [markdown]
# ### <font color='red'>plt.figure()</font> $\Rightarrow$ Erlaubt uns Anpassungen an der Form und Größe der Plots vorzunehmen.
#
# ### Schema: figure(num=None, figsize=None, dpi=None, facecolor=None, edgecolor=None, frameon=True)

# %%
plt.figure(figsize=(10,10))
plt.plot(y)
plt.show()

# %% [markdown]
# ### <font color='red'>plt.legend()</font> $\Rightarrow$ Erlaubt uns Anpassungen an den Labels der Datenpunkte innerhalb eines Plots vorzunehmen.
#
# ### Schema: legend([handles], labels, [loc], [prop], [fontsize], [facecolor], ...)

# %%
custom_label = "Ein paar Zahlen"
plt.figure(figsize=(10,10))
plt.plot(y, label=custom_label)
plt.legend(loc='upper left', fontsize=20)
plt.show()

# %% [markdown]
# # Aufgabe 1:
#
# Zeichne eine Exponential-Funktion für x 1-12. Hint: Numpy bietet die Funktion np.exp() an.

# %%
x = np.arange(1,20)
y = np.exp(x)

# %%
plt.plot(x,y);

# %% [markdown]
# ## 1.1 Bar Graph

# %%
x = np.arange(1950, 2020)

# %%
y = 2 * np.random.randn(1, len(x))

# %%
plt.bar(x,y[0])
plt.show();

# %%
df = pd.DataFrame(y[0], dtype='float', columns=['y'], index=x)

# %%
# Ziel: Alle über 0 rot färben, alle unter null grau färben 
clrs = ['red' if x > 0 else 'grey' for x in df.y]

# Ziel Alle die über dem Mittelwert sind rot färben und alle unter Mittelwert grau färben
#clrs = ['red' if (x >= np.mean(df.y)) else 'grey' for x in df.y]

# %%
plt.bar(df.index, df.y, color=clrs)
# Out:
# <BarContainer object of 70 artists>

# %%
# Größe ändern 
plt.figure(figsize=(20,10))
plt.bar(df.index, df.y, label='Original')
plt.bar(df.index, -df.y, label='Inversed')
plt.legend()
plt.show()

# %% [markdown]
# ## 1.2 Line Chart (Stacked Plot)

# %%
rng = np.arange(50)
rnd = np.random.randint(0, 10, size=(3, rng.size))
yrs = 1950 + rng

fig, ax = plt.subplots(figsize=(5, 3))
ax.stackplot(yrs, rng + rnd, labels=['Eastasia', 'Eurasia', 'Oceania'])
ax.set_title('Combined debt growth over time')
ax.legend(loc='upper left')
ax.set_ylabel('Total debt')
ax.set_xlim(xmin=yrs[0], xmax=yrs[-1])
fig.tight_layout()

# %%
first_value = plt.plot(yrs, rnd[0] + rng)

# %%
second_value = plt.plot(yrs, rnd[1] + rng)

# %%
second_value = plt.plot(yrs, rnd[2] + rng)

# %%
x = [1, 2, 3, 4, 5]
y1 = [1, 1, 2, 3, 5]
y2 = [0, 4, 2, 6, 8]
y3 = [1, 3, 5, 7, 9]

y = np.vstack([y1, y2, y3])

labels = ["Fibonacci ", "Evens", "Odds"]

fig, ax = plt.subplots()
ax.stackplot(x, y1, y2, y3, labels=labels)
ax.legend(loc='upper left')
plt.show()

# %%
fig, ax = plt.subplots()
ax.stackplot(x, y, labels=labels)
ax.legend(loc='upper left')
plt.show();

# %%
y = np.random.randn(1,100000)
y_2 = np.random.normal(10,0.5,100000)

# %% [markdown]
# ## 1.3 Histogram

# %% [markdown]
# Scaling mit xlim und ylim --> Unterschied in der Visualisierung der gleichen Verteilung kann riesig sein.

# %%
plt.hist(y[0], bins=10);

# %%
plt.hist(y[0], bins=1000);

# %%
plt.hist(y_2, bins=1000)
plt.xlim(1,20);

# %%
plt.hist(y_2, bins=1000)
plt.xlim(10,11)
plt.ylim(0,200);

# %%
mu, sigma = 10, 1.2
s = np.random.normal(mu, sigma, 10000)
count, bins, ignored = plt.hist(s, 300, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
               np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
         linewidth=2, color='r')
plt.show()

# %% [markdown]
# # Short introduction to Pandas

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv'
from mat
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1243         """Send a complete request to the server."""
# -> 1244         self._send_request(method, url, body, headers, encode_chunked)
#    1245
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1289             body = _encode(body, 'body')
# -> 1290         self.endheaders(body, encode_chunked=encode_chunked)
#    1291
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1238             raise CannotSendHeader()
# -> 1239         self._send_output(message_body, encode_chunked=encode_chunked)
#    1240
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in send(self, data)
#     965             if self.auto_open:
# --> 966                 self.connect()
#     967             else:
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in connect(self)
#    1405
# -> 1406             super().connect()
#    1407
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in connect(self)
#     937         self.sock = self._create_connection(
# --> 938             (self.host,self.port), self.timeout, self.source_address)
#     939         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# ~\AppData\Local\Continuum\anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     706     err = None
# --> 707     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     708         af, socktype, proto, canonname, sa = res
#
# ~\AppData\Local\Continuum\anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-55-eb5df661d4bd> in <module>
#       1 import urllib.request
#       2 url = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv'
# ----> 3 a = urllib.request.urlopen(url)
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in https_open(self, req)
#    1358         def https_open(self, req):
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#    1362         https_request = AbstractHTTPHandler.do_request_
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
# -> 1319                 raise URLError(err)
#    1320             r = h.getresponse()
#    1321         except:
#
# URLError: <urlopen error [Errno 11001] getaddrinfo failed>

# %%
## Importiere einen Datensatz 
iris = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1243         """Send a complete request to the server."""
# -> 1244         self._send_request(method, url, body, headers, encode_chunked)
#    1245
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1289             body = _encode(body, 'body')
# -> 1290         self.endheaders(body, encode_chunked=encode_chunked)
#    1291
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1238             raise CannotSendHeader()
# -> 1239         self._send_output(message_body, encode_chunked=encode_chunked)
#    1240
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in send(self, data)
#     965             if self.auto_open:
# --> 966                 self.connect()
#     967             else:
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in connect(self)
#    1405
# -> 1406             super().connect()
#    1407
#
# ~\AppData\Local\Continuum\anaconda3\lib\http\client.py in connect(self)
#     937         self.sock = self._create_connection(
# --> 938             (self.host,self.port), self.timeout, self.source_address)
#     939         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# ~\AppData\Local\Continuum\anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     706     err = None
# --> 707     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     708         af, socktype, proto, canonname, sa = res
#
# ~\AppData\Local\Continuum\anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-56-3d4b86e9e482> in <module>
#       1 ## Importiere einen Datensatz
# ----> 2 iris = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     438     # See https://github.com/python/mypy/issues/1297
#     439     fp_or_buf, _, compression, should_close = get_filepath_or_buffer(
# --> 440         filepath_or_buffer, encoding, compression
#     441     )
#     442     kwds["compression"] = compression
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode)
#     194
#     195     if _is_url(filepath_or_buffer):
# --> 196         req = urlopen(filepath_or_buffer)
#     197         content_encoding = req.headers.get("Content-Encoding", None)
#     198         if content_encoding == "gzip":
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in https_open(self, req)
#    1358         def https_open(self, req):
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#    1362         https_request = AbstractHTTPHandler.do_request_
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
# -> 1319                 raise URLError(err)
#    1320             r = h.getresponse()
#    1321         except:
#
# URLError: <urlopen error [Errno 11001] getaddrinfo failed>

# %% [markdown]
# # Dataframe? Was ist das?
#
# * Here is how the Technical Definition looks like <br>
# ->    *Pandas DataFrame is a 2-D labeled data structure with columns of potentially different type.*
# * And here is how you should understand it <br>
# ->    *Pandas DataFrame is nothing but an in-memory representation of an excel sheet via Python programming language*

# %% [markdown]
# ## 1.0 describe()
# Gibt Statistiken für numerische Variablen innerhalb eines Dataframes in Form einer Zusammenfassung aus

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ## 2.0 info()
# Gibt informationen zu den einzelnen Spalten aus --> Fehlende Werte, Datentyp, Memory Usage, etc.

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ## 3.0 Überblick über Daten verschaffen mit head(), tail(), etc.

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# # EDA or Explanatory Data Analysis

# %%
from sklearn.datasets import load_boston

# %%
load_boston()

boston_data = load_boston()
# Load boston into a dataframe and set the field names
df = pd.DataFrame(boston_data['data'], columns=boston_data['feature_names'])

# %%
print(boston_data.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
#         - PTRATIO  pupil-teacher ratio by town
#         - B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#         - LSTAT    % lower status of the population
#         - MEDV     Median value of owner-occupied homes in $1000's
#
#     :Missing Attribute Values: None
#
#     :Creator: Harrison, D. and Rubinfeld, D.L.
#
# This is a copy of UCI ML housing dataset.
# https://archive.ics.uci.edu/ml/machine-learning-databases/housing/
#
#
# This dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
#
# The Boston house-price data has been used in many machine learning papers that address regression
# problems.
#
# .. topic:: References
#
#    - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.
#    - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.

# %%
# Hier werden die y Werte gespeichert
price = boston_data.target
df['Price'] = price

# %%
# Statistische Zusammenfassung der Werte im df 
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT       Price
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
# Info über fehlende Werte, Datentypen, etc. 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
# CRIM       506 non-null float64
# ZN         506 non-null float64
# INDUS      506 non-null float64
# CHAS       506 non-null float64
# NOX        506 non-null float64
# RM         506 non-null float64
# AGE        506 non-null float64
# DIS        506 non-null float64
# RAD        506 non-null float64
# TAX        506 non-null float64
# PTRATIO    506 non-null float64
# B          506 non-null float64
# LSTAT      506 non-null float64
# Price      506 non-null float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
df.plot(kind='scatter', x='RM', y='Price');

# %%
df.plot(kind='scatter', x='LSTAT', y='Price');

# %%
# Histograms
df.hist('Price')
plt.show()

# %%
# Histograms
df.hist('RM')
plt.show()

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style  type="text/css" >
#     #T_f13d63fe_fce3_11ea_8f67_5076af91130crow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow0_col1 {
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow0_col2 {
#             background-color:  #f7b89c;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow0_col3 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow0_col4 {
#             background-color:  #f7b599;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow0_col5 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow0_col6 {
#             background-color:  #f5c1a9;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow0_col7 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow0_col8 {
#             background-color:  #f08a6c;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow0_col9 {
#             background-color:  #f39475;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow0_col10 {
#             background-color:  #f2cbb7;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow0_col11 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow0_col12 {
#             background-color:  #f7af91;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow0_col13 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow1_col0 {
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow1_col2 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow1_col3 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow1_col4 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow1_col5 {
#             background-color:  #f3c8b2;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow1_col6 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow1_col7 {
#             background-color:  #ec7f63;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow1_col8 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow1_col9 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow1_col10 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow1_col11 {
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow1_col12 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow1_col13 {
#             background-color:  #f5c0a7;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow2_col0 {
#             background-color:  #f7b89c;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow2_col1 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow2_col3 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow2_col4 {
#             background-color:  #e0654f;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow2_col5 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow2_col6 {
#             background-color:  #ee8468;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow2_col7 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow2_col8 {
#             background-color:  #f29072;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow2_col9 {
#             background-color:  #e57058;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow2_col10 {
#             background-color:  #f6bda2;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow2_col11 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow2_col12 {
#             background-color:  #f18f71;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow2_col13 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow3_col0 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow3_col1 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow3_col2 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow3_col4 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow3_col5 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow3_col6 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow3_col7 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow3_col8 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow3_col9 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow3_col10 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow3_col11 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow3_col12 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow3_col13 {
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow4_col0 {
#             background-color:  #f7b599;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow4_col1 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow4_col2 {
#             background-color:  #e0654f;
#             color:  #000000;
#         }    #T_f13d63fe_fce3_11ea_8f67_5076af91130crow4_col3 {
#             background-color:  #d9dce1;
#             colo

# %%
corr_bound = corr.where(corr>0.70)
corr_bound.style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# C:\Users\SoenkeMorrow\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_f15edf30_fce3_11ea_a6f1_5076af91130crow0_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow0_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow0_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow0_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow0_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow0_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow0_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow0_col12 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow0_col13 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow1_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow1_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow1_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow1_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow1_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow1_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow1_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow1_col12 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow1_col13 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow2_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow2_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow2_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow2_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow2_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow2_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow2_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow2_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow2_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow2_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow2_col12 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow2_col13 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow3_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow3_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow3_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow3_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow3_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow3_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow3_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow3_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow3_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow3_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow3_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow3_col11 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow3_col12 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow3_col13 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow4_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow4_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow4_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_f15edf30_fce3_11ea_a6f1_5076af91130crow4_col3 {
#             background-color:  #3b4cc0;
#             colo

# %%
import seaborn as sns

threshold = 0.9
#df_corr = df.corr(method='pearson', min_periods=1)
#df_correlated = ~(df_corr.mask(np.tril(np.ones([len(df_corr)]*2, dtype=bool))).abs() > threshold).any()
#corr_idx = df_correlated.loc[df_correlated[df_correlated.index] == False].index
#df_out = df[corr_idx]




high_corr = df_corr.abs() > threshold
s = high_corr.stack()
s_final = s[s].index.tolist()

# %%
corr_matrix = df.corr().abs()
high_corr_var=np.where(corr_matrix>0.8)
high_corr_var=[(corr_matrix.columns[x],corr_matrix.columns[y]) for x,y in zip(*high_corr_var) if x!=y and x<y]
high_corr_var
# Out:
# [('RAD', 'TAX')]

# %%
def trimm_correlated(df_in, threshold):
    df_corr = df_in.corr(method='pearson', min_periods=1)
    df_not_correlated = ~(df_corr.mask(np.tril(np.ones([len(df_corr)]*2, dtype=bool))).abs() > threshold).any()
    un_corr_idx = df_not_correlated.loc[df_not_correlated[df_not_correlated.index] == True].index
    df_out = df_in[un_corr_idx]
    return df_out

# %%
trimm_correlated(df, 0.6)
# Out:
#         CRIM    ZN  INDUS  CHAS     RM  PTRATIO       B
# 0    0.00632  18.0   2.31   0.0  6.575     15.3  396.90
# 1    0.02731   0.0   7.07   0.0  6.421     17.8  396.90
# 2    0.02729   0.0   7.07   0.0  7.185     17.8  392.83
# 3    0.03237   0.0   2.18   0.0  6.998     18.7  394.63
# 4    0.06905   0.0   2.18   0.0  7.147     18.7  396.90
# ..       ...   ...    ...   ...    ...      ...     ...
# 501  0.06263   0.0  11.93   0.0  6.593     21.0  391.99
# 502  0.04527   0.0  11.93   0.0  6.120     21.0  396.90
# 503  0.06076   0.0  11.93   0.0  6.976     21.0  396.90
# 504  0.10959   0.0  11.93   0.0  6.794     21.0  393.45
# 505  0.04741   0.0  11.93   0.0  6.030     21.0  396.90
#
# [506 rows x 7 columns]

# %%
import seaborn as sns
from sklearn import preprocessing
# Let's scale the columns before plotting them against MEDV
min_max_scaler = preprocessing.MinMaxScaler()
column_sels = ['LSTAT', 'INDUS', 'NOX', 'PTRATIO', 'RM', 'TAX', 'DIS', 'AGE']
x = df.loc[:,column_sels]
y = df['Price']
x = pd.DataFrame(data=min_max_scaler.fit_transform(x), columns=column_sels)
fig, axs = plt.subplots(ncols=4, nrows=2, figsize=(20, 10))
index = 0
axs = axs.flatten()
for i, k in enumerate(column_sels):
    sns.regplot(y=y, x=x[k], ax=axs[i])
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)

# %%
df['Price'].quantile(0.05)
df['Price'].quantile(0.95)
df['Price'].quantile(0.5) # median
# Out:
# 21.2

# %%
df.boxplot()

# %%
plt.boxplot(df['Price'], showmeans=True)
plt.show()

# %%
plt.boxplot(df['RM'], showmeans=True, notch=True)
plt.show()

# %%
plt.boxplot(df['AGE'], showmeans=True)
plt.show()

# %%
plt.boxplot(df['TAX'], showmeans=True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

def f(x, sigma):
    epsilon = np.random.randn(*x.shape) * sigma
    return 10 * np.sin(2 * np.pi * (x)) + epsilon

train_size = 10000
noise = 1.7

X = np.linspace(-0.5, 0.5, train_size).reshape(-1, 1)
y = f(X, sigma=noise).ravel()
y_true = f(X, sigma=0.0)

# %%
from sklearn.svm import SVR
svr_rbf = SVR(kernel='rbf', C=1000, gamma=0.3, epsilon=.2)
svr_rbf.fit(X, y)
# Out:
# SVR(C=1000, cache_size=200, coef0=0.0, degree=3, epsilon=0.2, gamma=0.3,
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
plt.figure(figsize=(20,10))
plt.scatter(X, y, alpha=0.3)
plt.plot(X, svr_rbf.predict(X), '-', label='Prediction', color='r')
plt.plot(X, y_true, '--', label='Ground Truth')
plt.title('Fit a Function to Training Data and Predict Values')
plt.legend();

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

def f(x, sigma):
    epsilon = np.random.randn(*x.shape) * sigma
    return 10 * np.cos(2 * np.pi * (x)) + epsilon

train_size = 1000
noise = 1.7

X = np.linspace(-0.5, 0.5, train_size).reshape(-1, 1)
y = f(X, sigma=noise).ravel()
y_true = f(X, sigma=0.0)

# %%
from sklearn.svm import SVR
svr_rbf = SVR(kernel='rbf', C=10000, gamma=0.1, epsilon=0.1)
svr_rbf.fit(X, y)
# Out:
# SVR(C=10000, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma=0.1,
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
plt.figure(figsize=(20,10))
plt.scatter(X, y, alpha=0.3)
plt.plot(X, svr_rbf.predict(X), '-', label='Prediction', color='r')
plt.plot(X, y_true, '--', label='Ground Truth')
plt.title('Fit a Function to Training Data and Predict Values')
plt.legend();
